# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'

# %%
data = pd.read_csv('order_insert.csv',header = 0)

# %%
data_1 = pd.read_csv('paper_figure/random65536_insertion_top_down_insertion_layer.csv',header = 0)
data_2 = pd.read_csv('paper_figure/random131072_insertion_top_down_insertion_layer.csv',header = 0)
data_3 = pd.read_csv('paper_figure/random262144_insertion_top_down_insertion_layer.csv',header = 0)
data_4 = pd.read_csv('paper_figure/random524288_insertion_top_down_insertion_layer.csv',header = 0)
data_5 = pd.read_csv('paper_figure/random1048576_insertion_top_down_insertion_layer.csv',header = 0)

# %%
x_axix = [0,1,2,3,4]
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
plt.axes(yscale = 'log')
#plt.plot(x_axix,min,color = 'black',label = 'active miner')
plt.plot(x_axix,data['aios'],marker='+',color = 'green',label = 'AM')
#plt.scatter(x_axix,miner_2)
#plt.plot(x_axix,data_2['rato'],marker='.',color = 'red',label = 'G2')
#plt.scatter(x_axix,miner_5)
#plt.plot(x_axix,data_3['rato'],marker='o',color = 'skyblue',label = 'G3')
#plt.scatter(x_axix,miner_10)
#plt.plot(x_axix,data_4['rato'],marker='x',color = 'blue',label = 'G4')
#plt.scatter(x_axix,miner_20)
#plt.plot(x_axix,data_5['rato'],marker='*',color = 'purple',label = 'G5')
#plt.scatter(x_axix,miner_50)
plt.legend()
plt.xticks(x_axix,['1','10','100','1000','10000'])
plt.ylabel('Speedup ratio')
plt.savefig('./paper_figure/order_insert.pdf', bbox_inches= 'tight')
plt.show()

# %%
data_1 = pd.read_csv('paper_figure/random65536_removal_top_down_removal_layer.csv',header = 0)
data_2 = pd.read_csv('paper_figure/random131072_removal_top_down_removal_layer.csv',header = 0)
data_3 = pd.read_csv('paper_figure/random262144_removal_top_down_removal_layer.csv',header = 0)
data_4 = pd.read_csv('paper_figure/random524288_removal_top_down_removal_layer.csv',header = 0)
data_5 = pd.read_csv('paper_figure/random1048576_removal_top_down_removal_layer.csv',header = 0)

# %%
data_1 = pd.read_csv('paper_figure/random65536_insertion_top_down_insertion_compare.csv',header = 0)
data_2 = pd.read_csv('paper_figure/random131072_insertion_top_down_insertion_compare.csv',header = 0)
data_3 = pd.read_csv('paper_figure/random262144_insertion_top_down_insertion_compare.csv',header = 0)
data_4 = pd.read_csv('paper_figure/random524288_insertion_top_down_insertion_compare.csv',header = 0)
data_5 = pd.read_csv('paper_figure/random1048576_insertion_top_down_insertion_compare.csv',header = 0)

# %%
data_1 = pd.read_csv('paper_figure/random65536_removal_top_down_removal_compare.csv',header = 0)
data_2 = pd.read_csv('paper_figure/random131072_removal_top_down_removal_compare.csv',header = 0)
data_3 = pd.read_csv('paper_figure/random262144_removal_top_down_removal_compare.csv',header = 0)
data_4 = pd.read_csv('paper_figure/random524288_removal_top_down_removal_compare.csv',header = 0)
data_5 = pd.read_csv('paper_figure/random1048576_removal_top_down_removal_compare.csv',header = 0)

# %%
data_1 = pd.read_csv('paper_figure/random65536_insertion_bottom_up_insertion_compare.csv',header = 0)
data_2 = pd.read_csv('paper_figure/random131072_insertion_bottom_up_insertion_compare.csv',header = 0)
data_3 = pd.read_csv('paper_figure/random262144_insertion_bottom_up_insertion_compare.csv',header = 0)
data_4 = pd.read_csv('paper_figure/random524288_insertion_bottom_up_insertion_compare.csv',header = 0)
data_5 = pd.read_csv('paper_figure/random1048576_insertion_bottom_up_insertion_compare.csv',header = 0)

# %%
data_1 = pd.read_csv('paper_figure/random65536_removal_bottom_up_removal_compare.csv',header = 0)
data_2 = pd.read_csv('paper_figure/random131072_removal_bottom_up_removal_compare.csv',header = 0)
data_3 = pd.read_csv('paper_figure/random262144_removal_bottom_up_removal_compare.csv',header = 0)
data_4 = pd.read_csv('paper_figure/random524288_removal_bottom_up_removal_compare.csv',header = 0)
data_5 = pd.read_csv('paper_figure/random1048576_removal_bottom_up_removal_compare.csv',header = 0)

# %%
#plt.axes(xscale ='log')
#plt.plot(x_axix,miner,color = 'black',label = 'active miner')
plt.plot(data_1['time'],date_1[1],color = 'green',label = '2-active miner')
#plt.scatter(x_axix,miner_2,color = 'green')
plt.plot(dataset_5[0],dataset_5[1],color = 'red',label = '5-active miner')
#plt.scatter(x_axix,miner_5,color = 'red')
plt.plot(dataset_10[0],dataset_10[1],color = 'skyblue',label = '10-active miner')
#plt.scatter(x_axix,miner_10,color = 'skyblue')
plt.plot(dataset_20[0],dataset_20[1],color = 'blue',label = '20-active miner')
#plt.scatter(x_axix,miner_20,color = 'blue')
plt.plot(dataset_50[0],dataset_50[1],color = 'purple',label = '50-active miner')
#plt.scatter(x_axix,miner_50,color = 'purple')
plt.legend()
#plt.xticks(x_axix,[0,1,2,3,4,5,6,7])
plt.title('the duration of active miner')
plt.xlabel('miner interconnected duration(second)')
plt.ylabel('CDF')
plt.savefig('./figure/miner_duration.jpg', bbox_inches= 'tight')
plt.show()
